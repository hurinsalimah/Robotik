# %%
# Nama : Hurin Salimah
# NIM  : 1103200021

#import git
# !wget --no-check-certificate \
  https://github.com/dicodingacademy/assets/raw/main/ml_pengembangan_academy/Chessman-image-dataset.zip \
  -O /tmp/Chessman-image-dataset.zip
# Out:
# --2024-01-05 05:21:17--  https://github.com/dicodingacademy/assets/raw/main/ml_pengembangan_academy/Chessman-image-dataset.zip
# Resolving github.com (github.com)... 20.27.177.113
# Connecting to github.com (github.com)|20.27.177.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dicodingacademy/assets/main/ml_pengembangan_academy/Chessman-image-dataset.zip [following]
# --2024-01-05 05:21:18--  https://raw.githubusercontent.com/dicodingacademy/assets/main/ml_pengembangan_academy/Chessman-image-dataset.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60684125 (58M) [application/zip]
# Saving to: ‘/tmp/Chessman-image-dataset.zip’
#
# /tmp/Chessman-image 100%[===================>]  57.87M  63.2MB/s    in 0.9s
#
# 2024-01-05 05:21:19 (63.2 MB/s) - ‘/tmp/Chessman-image-dataset.zip’ saved [60684125/60684125]

# %%
#ekstrak dataset git
import os
import zipfile
local_zip = '/tmp/Chessman-image-dataset.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %%
#read isi direktori dataset
os.listdir('/tmp/Chessman-image-dataset/Chess')
# Out:
# ['Bishop', 'Rook', 'King', 'Pawn', 'Knight', 'Queen']

# %%
#menghitung jumlah data pada tiap direktori
print('total pawn images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Pawn')))
print('total King images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/King')))
print('total Knight images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Knight')))
print('total bishop images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Bishop')))
print('total queen images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Queen')))
print('total rook images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Rook')))
# Out:
# total pawn images : 107
# total King images : 76
# total Knight images : 106
# total bishop images : 87
# total queen images : 78
# total rook images : 102

# %%
#melihat salah satu sample dataset
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
img = image.load_img('/tmp/Chessman-image-dataset/Chess/Queen/00000001.jpg')
imgplot = plt.imshow(img)

# %%
#import image generator dan mengaplikasikan augmentasi gambar
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_dir = os.path.join('/tmp/Chessman-image-dataset/Chess')
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=20,
                                   zoom_range=0.2,
                                   shear_range=0.2,
                                   fill_mode='nearest',
                                   validation_split=0.1) #set validation split

# %%
#membagi data training dan data testing menggunakan parameter subset 'training'/'validation'
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(150, 150),
    batch_size=8,
    class_mode='categorical',
    subset='training'
) #set as training data
validation_generator = train_datagen.flow_from_directory(
    train_dir, #direktori yang sama dengan data train
    target_size=(150, 150),
    batch_size=16,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 499 images belonging to 6 classes.
# Found 52 images belonging to 6 classes.

# %%
#arsitektur model 3 layer convolution dan 2 hidden layer; 512 dan 256 unit perseptron
import tensorflow as tf
model = tf.keras.models.Sequential([
    #input shape 150x150 pixel dan 3 bytes warna
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),
    #flatten the result to feed into a DNN
    tf.keras.layers.Flatten(),
    #512 neuron hidden layer
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    #output dengan 1 neuron
    tf.keras.layers.Dense(6, activation='softmax')
])

# %%
#optimizer dan loss
model.compile(optimizer=tf.optimizers.Adam(),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(train_generator,
                              validation_data=validation_generator,
                              epochs=50,
                              verbose=2)
# Out:
# Epoch 1/50
# 63/63 - 51s - loss: 1.8211 - accuracy: 0.1764 - val_loss: 1.7860 - val_accuracy: 0.1923 - 51s/epoch - 811ms/step
# Epoch 2/50
# 63/63 - 44s - loss: 1.7873 - accuracy: 0.1804 - val_loss: 1.7793 - val_accuracy: 0.1923 - 44s/epoch - 706ms/step
# Epoch 3/50
# 63/63 - 42s - loss: 1.7778 - accuracy: 0.1844 - val_loss: 1.7763 - val_accuracy: 0.2115 - 42s/epoch - 660ms/step
# Epoch 4/50
# 63/63 - 42s - loss: 1.7604 - accuracy: 0.2465 - val_loss: 1.7610 - val_accuracy: 0.2692 - 42s/epoch - 664ms/step
# Epoch 5/50
# 63/63 - 42s - loss: 1.7203 - accuracy: 0.2806 - val_loss: 1.7281 - val_accuracy: 0.2115 - 42s/epoch - 672ms/step
# Epoch 6/50
# 63/63 - 44s - loss: 1.6978 - accuracy: 0.2766 - val_loss: 1.7632 - val_accuracy: 0.2500 - 44s/epoch - 697ms/step
# Epoch 7/50
# 63/63 - 43s - loss: 1.6837 - accuracy: 0.2986 - val_loss: 1.7079 - val_accuracy: 0.3269 - 43s/epoch - 685ms/step
# Epoch 8/50
# 63/63 - 44s - loss: 1.6456 - accuracy: 0.3026 - val_loss: 1.6051 - val_accuracy: 0.3462 - 44s/epoch - 695ms/step
# Epoch 9/50
# 63/63 - 54s - loss: 1.5513 - accuracy: 0.3988 - val_loss: 1.7030 - val_accuracy: 0.3077 - 54s/epoch - 851ms/step
# Epoch 10/50
# 63/63 - 45s - loss: 1.5635 - accuracy: 0.3707 - val_loss: 1.7399 - val_accuracy: 0.2115 - 45s/epoch - 711ms/step
# Epoch 11/50
# 63/63 - 43s - loss: 1.4700 - accuracy: 0.4309 - val_loss: 1.6531 - val_accuracy: 0.2692 - 43s/epoch - 685ms/step
# Epoch 12/50
# 63/63 - 44s - loss: 1.4867 - accuracy: 0.4148 - val_loss: 1.6188 - val_accuracy: 0.3462 - 44s/epoch - 700ms/step
# Epoch 13/50
# 63/63 - 43s - loss: 1.3928 - accuracy: 0.4609 - val_loss: 1.6841 - val_accuracy: 0.3269 - 43s/epoch - 680ms/step
# Epoch 14/50
# 63/63 - 46s - loss: 1.3228 - accuracy: 0.4749 - val_loss: 1.7001 - val_accuracy: 0.2885 - 46s/epoch - 726ms/step
# Epoch 15/50
# 63/63 - 44s - loss: 1.3303 - accuracy: 0.4910 - val_loss: 1.6405 - val_accuracy: 0.3462 - 44s/epoch - 702ms/step
# Epoch 16/50
# 63/63 - 44s - loss: 1.2290 - accuracy: 0.5150 - val_loss: 1.5953 - val_accuracy: 0.3654 - 44s/epoch - 706ms/step
# Epoch 17/50
# 63/63 - 56s - loss: 1.2152 - accuracy: 0.5391 - val_loss: 1.4925 - val_accuracy: 0.3269 - 56s/epoch - 894ms/step
# Epoch 18/50
# 63/63 - 45s - loss: 1.2199 - accuracy: 0.5150 - val_loss: 1.6639 - val_accuracy: 0.3269 - 45s/epoch - 720ms/step
# Epoch 19/50
# 63/63 - 44s - loss: 1.1654 - accuracy: 0.5671 - val_loss: 1.6016 - val_accuracy: 0.4038 - 44s/epoch - 705ms/step
# Epoch 20/50
# 63/63 - 43s - loss: 1.0853 - accuracy: 0.5792 - val_loss: 1.6879 - val_accuracy: 0.3269 - 43s/epoch - 686ms/step
# Epoch 21/50
# 63/63 - 45s - loss: 1.0933 - accuracy: 0.5671 - val_loss: 1.4458 - val_accuracy: 0.4423 - 45s/epoch - 707ms/step
# Epoch 22/50
# 63/63 - 44s - loss: 1.0175 - accuracy: 0.6253 - val_loss: 1.7608 - val_accuracy: 0.3269 - 44s/epoch - 705ms/step
# Epoch 23/50
# 63/63 - 44s - loss: 1.0122 - accuracy: 0.6232 - val_loss: 1.8247 - val_accuracy: 0.3077 - 44s/epoch - 697ms/step
# Epoch 24/50
# 63/63 - 44s - loss: 0.9423 - accuracy: 0.6273 - val_loss: 1.4498 - val_accuracy: 0.5385 - 44s/epoch - 699ms/step
# Epoch 25/50
# 63/63 - 44s - loss: 0.9010 - accuracy: 0.6754 - val_loss: 1.6028 - val_accuracy: 0.4231 - 44s/epoch - 699ms/step
# Epoch 26/50
# 63/63 - 45s - loss: 0.8642 - accuracy: 0.6774 - val_loss: 1.6330 - val_accuracy: 0.4038 - 45s/epoch - 720ms/step
# Epoch 27/50
# 63/63 - 43s - loss: 0.8322 - accuracy: 0.6914 - val_loss: 1.6822 - val_accuracy: 0.4808 - 43s/epoch - 682ms/step
# Epoch 28/50
# 63/63 - 44s - loss: 0.8194 - accuracy: 0.7014 - val_loss: 1.8095 - val_accuracy: 0.3654 - 44s/epoch - 705ms/step
# Epoch 29/50
# 63/63 - 45s - loss: 0.7721 - accuracy: 0.7074 - val_loss: 1.8431 - val_accuracy: 0.4038 - 45s/epoch - 707ms/step
# Epoch 30/50
# 63/63 - 43s - loss: 0.7494 - accuracy: 0.7154 - val_loss: 2.0114 - val_accuracy: 0.3077 - 43s/epoch - 686ms/step
# Epoch 31/50
# 63/63 - 44s - loss: 0.7512 - accuracy: 0.7114 - val_loss: 1.7125 - val_accuracy: 0.3269 - 44s/epoch - 695ms/step
# Epoch 32/50
# 63/63 - 43s - loss: 0.7110 - accuracy: 0.7315 - val_loss: 1.9960 - val_accuracy: 0.4038 - 43s/epoch - 683ms/step
# Epoch 33/50
# 63/63 - 44s - loss: 0.6672 - accuracy: 0.7295 - val_loss: 2.1562 - val_accuracy: 0.4423 - 44s/epoch - 696ms/step
# Epoch 34/50
# 63/63 - 44s - loss: 0.6645 - accuracy: 0.7315 - val_loss: 1.8297 - val_accuracy: 0.4615 - 44s/epoch - 705ms/step
# Epoch 35/50
# 63/63 - 45s - loss: 0.6061 - accuracy: 0.7856 - val_loss: 1.6731 - val_accuracy: 0.5192 - 45s/epoch - 713ms/step
# Epoch 36/50
# 63/63 - 45s - loss: 0.6331 - accuracy: 0.7916 - val_loss: 1.4991 - val_accuracy: 0.5000 - 45s/epoch - 719ms/step
# Epoch 37/50
# 63/63 - 45s - loss: 0.5530 - accuracy: 0.7996 - val_loss: 1.8726 - val_accuracy: 0.4615 - 45s/epoch - 711ms/step
# Epoch 38/50
# 63/63 - 45s - loss: 0.6300 - accuracy: 0.7756 - val_loss: 1.6559 - val_accuracy: 0.4808 - 45s/epoch - 713ms/step
# Epoch 39/50
# 63/63 - 44s - loss: 0.6552 - accuracy: 0.7655 - val_loss: 1.5269 - val_accuracy: 0.5769 - 44s/epoch - 698ms/step
# Epoch 40/50
# 63/63 - 45s - loss: 0.4978 - accuracy: 0.8176 - val_loss: 1.6588 - val_accuracy: 0.5000 - 45s/epoch - 710ms/step
# Epoch 41/50
# 63/63 - 44s - loss: 0.4560 - accuracy: 0.8557 - val_loss: 1.8639 - val_accuracy: 0.4808 - 44s/epoch - 696ms/step
# Epoch 42/50
# 63/63 - 44s - loss: 0.5101 - accuracy: 0.8076 - val_loss: 2.2110 - val_accuracy: 0.4231 - 44s/epoch - 696ms/step
# Epoch 43/50
# 63/63 - 46s - loss: 0.5576 - accuracy: 0.8277 - val_loss: 1.8060 - val_accuracy: 0.4615 - 46s/epoch - 722ms/step
# Epoch 44/50
# 63/63 - 44s - loss: 0.4338 - accuracy: 0.8437 - val_loss: 1.7554 - val_accuracy: 0.4231 - 44s/epoch - 703ms/step
# Epoch 45/50
# 63/63 - 44s - loss: 0.4597 - accuracy: 0.8397 - val_loss: 1.9595 - val_accuracy: 0.4808 - 44s/epoch - 691ms/step
# Epoch 46/50
# 63/63 - 45s - loss: 0.4718 - accuracy: 0.8377 - val_loss: 1.9602 - val_accuracy: 0.5192 - 45s/epoch - 713ms/step
# Epoch 47/50
# 63/63 - 44s - loss: 0.3981 - accuracy: 0.8737 - val_loss: 1.8872 - val_accuracy: 0.5000 - 44s/epoch - 702ms/step
# Epoch 48/50
# 63/63 - 43s - loss: 0.4692 - accuracy: 0.8517 - val_loss: 1.6921 - val_accuracy: 0.5000 - 43s/epoch - 684ms/step
# Epoch 49/50
# 63/63 - 44s - loss: 0.3797 - accuracy: 0.8637 - val_loss: 2.1770 - val_accuracy: 0.4615 - 44s/epoch - 697ms/step
# Epoch 50/50
# 63/63 - 43s - loss: 0.4309 - accuracy: 0.8457 - val_loss: 2.2320 - val_accuracy: 0.3269 - 43s/epoch - 683ms/step

# %%
#plot loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
#plot akurasi
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Akurasi Model')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
